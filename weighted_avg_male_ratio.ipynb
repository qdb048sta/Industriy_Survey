# %%
import os
os.chdir("D:\\User_Data\\Desktop\\kan-2\\industrial_census\\")

# %%
import pandas as pd
new_df=pd.DataFrame()
df=pd.read_excel("empty_csv.xlsx",sheet_name="1954")
df=df.iloc[:23]
df=df.fillna(0)
df["Food and beverage stores_M"]=df["Food and beverage stores_M"]+df["Food and beverage stores_M_1"]
df["Food and beverage stores_F"]=df["Food and beverage stores_F"]+df["Food and beverage stores_F_1"]
df=df.drop(columns=["Food and beverage stores_M_1"])
df=df.drop(columns=["Food and beverage stores_F_1"])
df["Finance and Insurance_M"]=df["Finance and Insurance_M_1"]+df["Finance and Insurance_M_2"]+df["Finance and Insurance_M_3"]
df["Finance and Insurance_F"]=df["Finance and Insurance_F_1"]+df["Finance and Insurance_F_2"]+df["Finance and Insurance_F_3"]
df["Finance and Insurance_M"]=df["Finance and Insurance_M"]+df["Real Estate and Rental and Leasing_M"]
df["Finance and Insurance_F"]=df["Finance and Insurance_F"]+df["Real Estate and Rental and Leasing_F"]
df=df.drop(columns=["Real Estate and Rental and Leasing_M","Real Estate and Rental and Leasing_F"])
df=df.drop(columns=["Finance and Insurance_M_1"])
df=df.drop(columns=["Finance and Insurance_M_2"])
df=df.drop(columns=["Finance and Insurance_M_3"])
df=df.drop(columns=["Finance and Insurance_F_1"])
df=df.drop(columns=["Finance and Insurance_F_2"])
df=df.drop(columns=["Finance and Insurance_F_3"])
df["Arts, entertainment, and recreation_M"]=df["Arts, entertainment, and recreation_M_1"]+df["Arts, entertainment, and recreation_M_2"]+df["Arts, entertainment, and recreation_M_3"]
df["Arts, entertainment, and recreation_F"]=df["Arts, entertainment, and recreation_F_1"]+df["Arts, entertainment, and recreation_F_2"]+df["Arts, entertainment, and recreation_F_3"]
df=df.drop(columns=["Arts, entertainment, and recreation_M_1"])
df=df.drop(columns=["Arts, entertainment, and recreation_M_2"])
df=df.drop(columns=["Arts, entertainment, and recreation_F_1"])
df=df.drop(columns=["Arts, entertainment, and recreation_F_2"])
df=df.drop(columns=["Arts, entertainment, and recreation_M_3"])
df=df.drop(columns=["Arts, entertainment, and recreation_F_3"])
df["Other Retail_M"]=df["Other Retail_M_1"]+df["Other Retail_M"]
df["Other Retail_F"]=df["Other Retail_F_1"]+df["Other Retail_F"]
df["Merchant Wholesale_M"]=df["Merchant Wholesale_M_1"]+df["Merchant Wholesale_M"]
df["Merchant_Wholesale_F"]=df["Merchant Wholesale_F_1"]+df["Merchant Wholesale_F"]
df=df.drop(columns=["Other Retail_M_1","Other Retail_F_1","Merchant Wholesale_M_1","Merchant Wholesale_F_1"])
df=df.drop([16])
df=df.drop([21])
columns=df.columns
for i in range(len(columns[1:])):
    if i%2==1:
        total=df[columns[i]]+df[columns[i+1]]
        new_df[columns[i][:-2]]=total
new_df.index=df[df.columns[0]]
new_df["Coal mining"]=round(new_df["Coal mining"]*((46065+9351)/428))
new_df["Utilities"]=new_df["Utilities"]+new_df["Water"]+new_df["Gas"]
new_df_1954=new_df

# %%
import pandas as pd
new_df=pd.DataFrame()
df=pd.read_excel("empty_csv.xlsx",sheet_name="1966")
df=df.iloc[:23]
df=df.fillna(0)
df=df.drop([16])
df=df.drop([21])
df["Finance and Insurance_M"]=df["Finance and Insurance_M"]+df["Real Estate and Rental and Leasing_M"]
df["Finance and Insurance_F"]=df["Finance and Insurance_F"]+df["Real Estate and Rental and Leasing_F"]
df=df.drop(columns=["Real Estate and Rental and Leasing_M","Real Estate and Rental and Leasing_F"])
df["Other Retail_M"]=df["Merchant Wholesale_M"]*(241786/300699)
df["Merchant Wholesale_M"]=df["Merchant Wholesale_M"]*(57105/300699)
columns=df.columns
for i in range(len(columns[1:])):
    if i%2==1:
        total=df[columns[i]]+df[columns[i+1]]
        new_df[columns[i][:-2]]=total
new_df.index=df[df.columns[0]]
new_df["Crop production"]=new_df["Crop production"]*20
new_df["Truck transportation"]=round(new_df["Truck transportation"]*((11883+26844+8510+936)/218854))
new_df["Water transportation"]=round(new_df["Water transportation"]*((7239+643)/1365634))
new_df["Warehousing and storage"]=round(new_df["Warehousing and storage"]*((1292+168)/1179179))
new_df_1966=new_df

# %%
import pandas as pd
new_df=pd.DataFrame()
df=pd.read_excel("empty_csv.xlsx",sheet_name="1976")
df=df.iloc[:21]
df=df.fillna(0)
df["Finance and Insurance_M"]=df["Finance and Insurance_M"]+df["Real Estate and Rental and Leasing_M"]
df["Finance and Insurance_F"]=df["Finance and Insurance_F"]+df["Real Estate and Rental and Leasing_F"]
df=df.drop(columns=["Real Estate and Rental and Leasing_M","Real Estate and Rental and Leasing_F"])
columns=df.columns
for i in range(len(columns[1:])):
    if i%2==1:
        total=df[columns[i]]+df[columns[i+1]]
        new_df[columns[i][:-2]]=total
new_df.index=df[df.columns[0]]
new_df_1976=new_df

# %%
new_df_1954["Other Transportation"]=new_df_1954["Air transportation"]+new_df_1954["Truck transportation"]+new_df_1954["Water transportation"]+new_df_1954["Transit and ground passenger transportation"]+new_df_1954["Services incidental to transportation"]
new_df_1966["Other Transportation"]=new_df_1966["Air transportation"]+new_df_1966["Truck transportation"]+new_df_1966["Water transportation"]+new_df_1966["Transit and ground passenger transportation"]+new_df_1966["Services incidental to transportation"]
new_df_1976["Other Transportation"]=new_df_1976["Air transportation"]+new_df_1976["Truck transportation"]+new_df_1976["Water transportation"]+new_df_1976["Transit and ground passenger transportation"]+new_df_1976["Services incidental to transportation"]
#new_df_1954["Fishing, hunting, and trapping"]=new_df_1954["Fishing, hunting, and trapping"]+new_df_1954["Logging"]+new_df_1954["Aquaculture"]
new_df_1966["Fishing, hunting, and trapping"]=new_df_1966["Fishing, hunting, and trapping"]+new_df_1966["Logging"]+new_df_1966["Aquaculture"]
new_df_1976["Fishing, hunting, and trapping"]=new_df_1976["Fishing, hunting, and trapping"]+new_df_1976["Logging"]+new_df_1976["Aquaculture"]
new_df_1954["Merchant Wholesale"]=new_df_1954["Merchant Wholesale"]+new_df_1954["Building material and garden equipment and supplies dealers"]+new_df_1954["Motor vehicle and parts dealers"]
new_df_1966["Merchant Wholesale"]=new_df_1966["Merchant Wholesale"]+new_df_1966["Building material and garden equipment and supplies dealers"]+new_df_1966["Motor vehicle and parts dealers"]
new_df_1976["Merchant Wholesale"]=new_df_1976["Merchant Wholesale"]+new_df_1976["Building material and garden equipment and supplies dealers"]+new_df_1976["Motor vehicle and parts dealers"]
new_df_1954["Other Retail"]=new_df_1954["Other Retail"]+new_df_1954["Miscellaneous store retailers"]
new_df_1966["Other Retail"]=new_df_1966["Other Retail"]+new_df_1966["Miscellaneous store retailers"]
new_df_1976["Other Retail"]=new_df_1976["Other Retail"]+new_df_1976["Miscellaneous store retailers"]
new_df_1954["Repair"]=new_df_1954["Automotive repair and maintenance (except car washes)"]
new_df_1966["Repair"]=new_df_1966["Automotive repair and maintenance (except car washes)"]
new_df_1976["Repair"]=new_df_1976["Automotive repair and maintenance (except car washes)"]

new_df_1954=new_df_1954.drop(columns=["Air transportation","Truck transportation","Water transportation","Logging","Motor vehicle and parts dealers","Building material and garden equipment and supplies dealers","Miscellaneous store retailers","Transit and ground passenger transportation","Services incidental to transportation",'Support activities for agriculture and forestry',
 'Support activities for mining','Warehousing and storage','Gasoline stations',
 'Management, administrative, and waste services',
 'Oil and gas extraction','Accommodation and food services',
 'Animal production',
 'Automotive repair and maintenance (except car washes)','Gas',
 'Merchant',
 'Other',
 'Total_manufacturing',
 'Water'])
new_df_1966=new_df_1966.drop(columns=["Air transportation","Truck transportation","Water transportation","Logging","Motor vehicle and parts dealers","Building material and garden equipment and supplies dealers","Aquaculture","Miscellaneous store retailers","Transit and ground passenger transportation","Services incidental to transportation",'Support activities for agriculture and forestry',
 'Support activities for mining','Warehousing and storage','Gasoline stations',
 'Management, administrative, and waste services',
 'Oil and gas extraction','Accommodation and food services',
 'Animal production',
 'Automotive repair and maintenance (except car washes)','Merchant',
 'Other',
 'Total_manufacturing',
 'Total_mining'])
new_df_1976=new_df_1976.drop(columns=["Air transportation","Truck transportation","Water transportation","Logging","Motor vehicle and parts dealers","Building material and garden equipment and supplies dealers","Aquaculture","Miscellaneous store retailers","Transit and ground passenger transportation","Services incidental to transportation",'Support activities for agriculture and forestry',
 'Support activities for mining','Warehousing and storage','Gasoline stations',
 'Management, administrative, and waste services',
 'Oil and gas extraction','Accommodation and food services',
 'Animal production',
 'Automotive repair and maintenance (except car washes)',"total_employee"])

# %%
recorded_industry=[[],[],[]]
weighted_average_ratio_1954=[]
for c in range(len(new_df_1954.index)):
    total_ratio_product=0
    total_employee=0
    for i in range(len(ratio_df.index)):
        if ratio_df["industry"][i] in new_df_1954.columns:
            recorded_industry[0].append(ratio_df["industry"][i])
            total_ratio_product=total_ratio_product+ratio_df["male to female ratio"][i]*new_df_1954[ratio_df["industry"][i]][new_df_1954.index[c]]
            total_employee=total_employee+new_df_1954[ratio_df["industry"][i]][new_df_1954.index[c]]
    weighted_average_ratio_1954.append(total_ratio_product/total_employee)
wavg_sex_ratio=pd.DataFrame()
wavg_sex_ratio["male_ratio"]=weighted_average_ratio_1954
wavg_sex_ratio["county"]=new_df_1954.index
wavg_sex_ratio.to_csv("wavg_sex_ratio_1954_6970.csv")

weighted_average_ratio_1966=[]
for c in range(len(new_df_1966.index)):
    total_ratio_product=0
    total_employee=0
    for i in range(len(ratio_df.index)):
        if ratio_df["industry"][i] in new_df_1966.columns:
            recorded_industry[1].append(ratio_df["industry"][i])
            total_ratio_product=total_ratio_product+ratio_df["male to female ratio"][i]*new_df_1966[ratio_df["industry"][i]][new_df_1966.index[c]]
            total_employee=total_employee+new_df_1966[ratio_df["industry"][i]][new_df_1966.index[c]]
    weighted_average_ratio_1966.append(total_ratio_product/total_employee)
wavg_sex_ratio=pd.DataFrame()
wavg_sex_ratio["male_ratio"]=weighted_average_ratio_1966
wavg_sex_ratio["county"]=new_df_1966.index
wavg_sex_ratio.to_csv("wavg_sex_ratio_1966_6970.csv")

weighted_average_ratio_1976=[]
for c in range(len(new_df_1976.index)):
    total_ratio_product=0
    total_employee=0
    for i in range(len(ratio_df.index)):
        if ratio_df["industry"][i] in new_df_1976.columns:
            recorded_industry[2].append(ratio_df["industry"][i])
            total_ratio_product=total_ratio_product+ratio_df["male to female ratio"][i]*new_df_1976[ratio_df["industry"][i]][new_df_1976.index[c]]
            total_employee=total_employee+new_df_1976[ratio_df["industry"][i]][new_df_1976.index[c]]
    weighted_average_ratio_1976.append(total_ratio_product/total_employee)
wavg_sex_ratio=pd.DataFrame()
wavg_sex_ratio["male_ratio"]=weighted_average_ratio_1976
wavg_sex_ratio["county"]=new_df_1976.index
wavg_sex_ratio.to_csv("wavg_sex_ratio_1976_6970.csv")
new_df_1954.to_csv("1954_total_employee.csv")
new_df_1966.to_csv("1966_total_employee.csv")
new_df_1976.to_csv("1976_total_employee.csv")

# %%
#ratio_df=pd.read_excel("data.xlsx")
ratio_df=pd.read_csv("total_employee_us_1969-70.csv")
ratio_df["male to female ratio"]=ratio_df["1969+70_sex_ratio"]

# %%
wavg_sex_ratio
# Out:
# Index(['male_ratio'], dtype='object')

# %%
set(new_df_1954.columns)-set(recorded_industry[0])
# Out:
# set()

# %%
ratio_df
# Out:
#                                              industry  no_gender_1969  \
# 0                                             no_data           10603
# 1                                         Neverworked               0
# 2                                     Crop production               0
# 3                                         Coal mining               0
# 4                                        Construction               0
# 5                          Wood product manufacturing               0
# 6                                           Furniture               0
# 7           Nonmetallic mineral product manufacturing               0
# 8                         Primary metal manufacturing               0
# 9              Fabricated metal product manufacturing               0
# 10                            Machinery manufacturing               0
# 11                                          Eletronic               0
# ...

# %%
new_df_1954.columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# e:\python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Aquaculture'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-320-acfd3a1704e0> in <module>
# ----> 1 new_df_1954["Aquaculture"]
# ...

# %%
new_df_1954.columns
# Out:
# Index(['Crop production', 'Animal production', 'Logging',
#        'Fishing, hunting, and trapping',
#        'Support activities for agriculture and forestry',
#        'Oil and gas extraction', 'Coal mining',
#        'Support activities for mining', 'Construction', 'Food manufacturing',
#        'Chemical manufacturing', 'Plastics and rubber products manufacturing',
#        'Nonmetallic mineral product manufacturing',
#        'Primary metal manufacturing', 'Fabricated metal product manufacturing',
#        'Machinery manufacturing', 'Transportation equipment manufacturing',
#        'Wood product manufacturing', 'Merchant Wholesale', 'Other Retail',
#        'Motor vehicle and parts dealers',
#        'Building material and garden equipment and supplies dealers',
#        'Food and beverage stores', 'Gasoline stations',
#        'Miscellaneous store retailers', 'Air transportation',
#        'Rail transportation', 'Water transportation', 'Truck transportation',
# ...
