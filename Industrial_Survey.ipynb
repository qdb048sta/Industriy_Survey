# %%
path="D:\\User_Data\\Downloads\\工商普查資料\\"
import pandas as pd
df=pd.read_csv(path+"65y.csv",encoding="big5")
# Out:
# e:\python\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (63) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.columns
# Out:
# Index(['普查編號', '鄉鎮市區代號', '貴單位是那一級的機構', '業別代號', '貴單位屬於那一種組織', '貴單位辦理何種登記',
#        '土地面積(平方公尺)', '建築物延面積(平方公尺)', '常僱員工－員工人數', '臨時員工－員工人數', '不支固定薪資人員－員工人數',
#        '合計－員工人數', '全年各項支出：物料及燃料耗用總值、營建材料耗用總值(營)、進貨金額(商)',
#        '全年各項支出：電力費用(礦製運)、存款利息支出(服)', '全年各項支出：兼銷貨品銷售成本(製運服)',
#        '全年各項支出：產品進貨(礦)、製成品及在製品全年進貨(製)、出售貨品或材料成本(營)、年初存貨價值(商)、倉儲支出(運)、保險給付(服)',
#        '全年各項支出：保安費提存(礦)、出售房地產土地成本(營)、年底存貨價值(商)、運費支出(運)、再保費支出(服)',
#        '全年各項支出：薪資支出', '全年各項支出：福利津貼', '全年各項支出：稅捐及規費', '全年各項支出：呆帳及移轉支出淨額',
#        '全年各項支出：各項折舊', '全年各項支出：佣金支出(運服)', '全年各項支出：租金支出', '全年各項支出：利息支出',
#        '全年各項支出：各項支出合計',
#        '全年各項收入：產品銷售收入(礦製)、向顧客承包工程額(營)、銷貨金額(商)、客運收入(運)、服務收入(服)',
#        '全年各項收入：貨運收入(運)、向同業分包入工程額(營)',
#        '全年各項收入：加工費收入(製)、服務(旅館)收入、分包出工程額(營)、倉儲收入(運)、金融業收入(服)',
#        '全年各項收入：修配收入(製)、出售自有自建房地產收入(營)、報關收入(運)、保險業收入(服)',
#        '全年各項收入：兼銷貨品銷售收入、出售貨品或材料收入(營)', '全年各項收入：佣金收入、修理裝配收入(營)',
#        '全年各項收入：其他營業收入', '全年各項收入：營業收入小計', '全年各項收入：利息收入', '全年各項收入：租金收入',
# ...

# %%
df[df["鄉鎮市區代號"].str.contains("台北市")]
# Out:
#               普查編號  鄉鎮市區代號           貴單位是那一級的機構     業別代號 貴單位屬於那一種組織  \
# 970     1316005082  台北市松山區              獨立經營的單位     1921     民營公司組織
# 971     1316801010  台北市松山區          有總管理單位的分支單位  石油及天然氣業         公營
# 972     1316831001  台北市松山區  有分支單位的總管理單位之本企業匯總資料      鐵礦業         公營
# 973     1316831002  台北市松山區   有分支單位的總管理單位之本單位的資料      煤礦業         公營
# 974     1316831003  台北市松山區              獨立經營的單位  化學與肥料礦業         公營
# ...            ...     ...                  ...      ...        ...
# 434290  6331821014  台北市北投區          有總管理單位的分支單位      典當業         公營
# 434291  6331902010  台北市北投區          有總管理單位的分支單位    本國銀行業         公營
# 434292  6331905023  台北市北投區          有總管理單位的分支單位    本國銀行業         公營
# 434293  6331907033  台北市北投區          有總管理單位的分支單位    本國銀行業         公營
# 434294  6331912038  台北市北投區          有總管理單位的分支單位    本國銀行業         公營
#
#                                       貴單位辦理何種登記  土地面積(平方公尺)  建築物延面積(平方公尺)  \
# 970                                         NaN          10             5
# ...
